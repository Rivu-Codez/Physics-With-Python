# %%
#IMPORTING MODULES
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#DEFINING VARIABLES AND CONSTANT g = 9.81 m/s^2
t = np.linspace(0, 10, 100)
v_0 = 0
g = 9.81
x_0 = v_0 * t + 0.5 * g * t**2
